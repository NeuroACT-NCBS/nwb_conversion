# %%
#code for converting 
from trodes_to_nwb.convert import create_nwbs
data_path = "/run/user/1002/gvfs/smb-share:server=storage2.ncbs.res.in,share=abhilashalab/NCBS/Supraja/Animals/Myna/na25/20250919/raw" 

output_dir = "/run/user/1002/gvfs/smb-share:server=storage2.ncbs.res.in,share=abhilashalab/NCBS/Supraja/Animals/Myna/na25/20250919/raw"
video_directory= "/run/user/1002/gvfs/smb-share:server=storage2.ncbs.res.in,share=abhilashalab/NCBS/Supraja/Animals/Myna/na25/20250919/raw"
query_expression = f"animal == 'na25' and date == 20250919"

create_nwbs(
    path=data_path,
    output_dir=output_dir,
    video_directory=video_directory,
    convert_video=True,
    behavior_only=True,
    n_workers=1,
    #header_reconfig_path=None,
    #device_metadata_paths=None,
    query_expression=query_expression,
)
# Out:
# 30-Oct-25 18:28:43 Creating NWB file for session: (np.int64(20250919), 'na25')
# ...
