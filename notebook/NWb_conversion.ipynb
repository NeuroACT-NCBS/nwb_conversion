# %%
#code for converting 
from trodes_to_nwb.convert import create_nwbs
data_path = "/media/NA_2_2025/Supraja/Animal/Koel/na20/raw/20250818" #Should be the path from storage server

output_dir = "/media/NA_2_2025/Supraja/Animal/Koel/na20/nwb" # should be to the spyglass folder in server

video_directory= "/media/NA_2_2025/Supraja/Animal/Myna/na20/video" # should be to the spyglass folder in server

query_expression = f"animal == 'na20' and date == 20250818"
create_nwbs(
    path=data_path,
    output_dir=output_dir,
    video_directory=video_directory,
    convert_video=True,
    behavior_only=True, # make it false for rec with neural data
    n_workers=1,
    #header_reconfig_path=None,
    #device_metadata_paths=None,
    query_expression=query_expression,
)

# %% [markdown]
# ## The bottom block should used for the rec file with neural data

# %%
from trodes_to_nwb.convert import create_nwbs
data_path = "/media/supraja/NA_2_2025/Supraja/Animal/Myna/mario/raw/20260414"

probe_metadata_paths = "/media/supraja/NA_2_2025/Supraja/Animal/Myna/mario/raw/20260414/A1x32-6mm-50-177-H32_21mm.yml" 

output_dir = "/media/supraja/NA_2_2025/Supraja/Animal/Myna/mario/nwb"

header_reconfig_path = "/media/supraja/NA_2_2025/Supraja/Animal/Myna/mario/raw/20260414/mario_reconfig.trodesconf"

video_directory= "/media/supraja/NA_2_2025/Supraja/Animal/Myna/mario/video"

query_expression = f"animal == 'mario' and date == 20260414"

create_nwbs(
    path=data_path,
    device_metadata_paths=[probe_metadata_paths],
    output_dir=output_dir,
    video_directory=video_directory,
    convert_video=True,
    #behavior_only=True,
    n_workers=1,
    header_reconfig_path=header_reconfig_path,
    query_expression=query_expression,
)
